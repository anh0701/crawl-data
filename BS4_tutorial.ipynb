# %% [markdown]
# ### 0. Giới thiệu BeautifulSoup
#
# 📌 Beautiful Soup(bs4) là 1 thư viện sử dụng để xử lí các thẻ trong XML, HTML
#
#
#
# - **3 BƯỚC ĐƠN GIẢN ĐỂ BẠN CÓ THỂ CRAWL ĐƯỢC BẰNG BS4**
# - BƯỚC 1: đọc cái trang web lên
# - BƯỚC 2: đọc thẻ HTML, tìm thẻ muốn tìm nó nằm ở đâu 🙂
# - BƯỚC 3: đọc doccument của bs4(nếu chưa thành thạo) ở đây https://www.crummy.com/software/BeautifulSoup/bs4/doc/ và sử dụng lệnh thích hợp để lấy nội dung mình cần
#
#
# > Chú ý:
# Dấu '>' có nghĩa là lấy thẻ thấp cấp hơn, dấu '~' có nghĩa là muốn lấy thẻ có cấp ngang hàng

# %%
# #cách cài đặt bs4
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\baobao\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\baobao\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\baobao\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Requirement already satisfied: requests in c:\users\baobao\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baobao\anaconda3\lib\site-packages (from requests) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\baobao\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\baobao\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\baobao\anaconda3\lib\site-packages (from requests) (1.26.11)

# %% [markdown]
# ### 1. Đọc dữ liệu từ một trang web

# %%
from urllib.request import urlopen

#cach 1
html = urlopen('http://pythonscraping.com/pages/page1.html')
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
#cach 2
import requests
html = requests.get('http://pythonscraping.com/pages/page1.html')
print("status: ", html.status_code)# status 200 là có thể crawl đc
print(html.text)
# Out:
# status:  200
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %% [markdown]
# ### 2. Làm quen với Beautiful Soup

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# html = urlopen('http://pythonscraping.com/pages/page1.html')
# bs = BeautifulSoup(html.read(), 'html.parser')
html = requests.get('http://pythonscraping.com/pages/page1.html')
bs = BeautifulSoup(html.text, 'html.parser')

# %%
bs
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %%
type(bs)
# Out:
# bs4.BeautifulSoup

# %%
bs.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.div
# Out:
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>

# %% [markdown]
# #### Cấu trúc HTML

# %% [markdown]
# ![html_structure](assets/html_structure.png)

# %% [markdown]
# ### Những ví dụ về việc kiểm soát lỗi khi đọc web
# Các lỗi có thể có:
# - Trang web không tồn tại trên server
# - Server không tồn tại

# %%
from urllib.request import urlopen
from urllib.error import HTTPError

try:
    html = urlopen('http://pythonscraping.com/pages/page1.html')
except HTTPError as e:
    print(e)
else:
    print('Không chạy vào except')
# Out:
# Không chạy vào except

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

try:
    html = urlopen('http://pythonscraping.com/pages/page1.html')
except HTTPError as e:
    print(e)
except URLError as e:
    print('Không thể tìm thấy server')
else:
    print('Nó đã chạy rồi nè hehe')
# Out:
# Nó đã chạy rồi nè hehe

# %% [markdown]
# ### 3. Một ví dụ về việc truy cập thẻ HTML không tồn tại trong Beautiful Soup

# %%
try:
    badContent = bs.nonExistingTag.anotherTag
except AttributeError as e:
    print('Không thể tìm thấy thẻ')
else:
    if badContent == None:
        print('Không thể tìm thấy thẻ')
    else:
        print(badContent)
# Out:
# Không thể tìm thấy thẻ

# %% [markdown]
# ### 4. Một ví dụ khác hoàn thiện hơn về việc lấy tiêu đề của một trang web

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup

def getTitle(url):
    try:
        # kiểm tra lỗi đọc địa chỉ trang web
        html = urlopen(url)
    except HTTPError as e:
        return None
    try:
        # kiểm tra lỗi đọc các thẻ HTML của trang web
        bs = BeautifulSoup(html.read(), 'html.parser')
        title = bs.body.h1
    except AttributeError as e:
        return None
    return title

title = getTitle('http://www.pythonscraping.com/pages/page1.html')

if title == None:
    print('Title could not be found')
else:
    print(title)
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# #### Có thể tìm hiểu sâu hơn: HTML
# #### Tips: Đọc trong sách để có thể tìm ra được các từ khóa khác.

# %% [markdown]
# ### 5. Một số lệnh crawl bằng bs4 thông dụng, ví dụ dưới đây chúng ta sẽ lấy dữ liệu của trang https://vnexpress.net/goc-nhin

# %%
from bs4 import BeautifulSoup
import requests

# đọc dữ liệu từ web
url = "https://vnexpress.net/goc-nhin"
html = requests.get(url)
html.text

# %%
html.status_code
# Out:
# 200

# %%
bs = BeautifulSoup(html.text, "html.parser")

# %%
# lấy 1 link đầu tiên trong trang https://vnexpress.net/goc-nhin
# lấy các link trong trang https://vnexpress.net/goc-nhin
one_link = bs.select_one('div[class="width_common list-news-subfolder list-stream-gocnhin"] > article > div > a')['href']
one_link
# Out:
# 'https://vnexpress.net/tac-gia/quan-the-dan-1447.html'

# %%
# lấy nhiều link trong trang https://vnexpress.net/goc-nhin
lst = bs.select('div[class="width_common list-news-subfolder list-stream-gocnhin"] > article > div > a')
link  = [i['href'] for i in lst]
link
# Out:
# ['https://vnexpress.net/tac-gia/quan-the-dan-1447.html',
#  'https://vnexpress.net/tac-gia/vo-nhat-vinh-1166.html',
#  'https://vnexpress.net/tac-gia/bui-minh-duc-1667.html',
#  'https://vnexpress.net/tac-gia/to-thuc-1053.html',
#  'https://vnexpress.net/tac-gia/tran-huu-hiep-1709.html',
#  'https://vnexpress.net/tac-gia/le-tran-quynh-1644.html',
#  'https://vnexpress.net/tac-gia/trinh-phuong-quan-1404.html',
#  'https://vnexpress.net/tac-gia/nguyen-quoc-dinh-1455.html',
#  'https://vnexpress.net/tac-gia/vu-ngoc-bao-1204.html',
#  'https://vnexpress.net/tac-gia/quan-the-dan-1447.html',
#  'https://vnexpress.net/tac-gia/mark-a-ashwill-1209.html',
#  'https://vnexpress.net/tac-gia/nguyen-van-tuan-1306.html',
#  'https://vnexpress.net/tac-gia/tran-huu-hiep-1709.html']

# %%
# lấy 1 thẻ p(thẻ chứa text) đầu tiên trong trang
one_text = bs.find('p')
one_text.text
# Out:
# 'Xem thêm »'

# %%
#lấy tất cả các thẻ p(thẻ chứa text) trong trang 
#find_all sẽ lấy nội dung tất cả các thẻ mà mình yêu cầu
full_card = bs.find_all('p')
full_text  = [i.text.replace('\n', '').strip() for i in full_card] # lệnh replace để đổi tất cả các kí tự '\n' thành ''
full_text
# Out:
# ['Xem thêm »',
#  'Nhiều phụ huynh nôn nóng muốn trẻ khỏi bệnh ngay, nên đã cho con dùng kháng sinh, kháng viêm khi chưa cần thiết.',
#  'Quan Thế Dân',
#  "Giáo viên vô tình trở thành lực lượng 'đòi nợ' khi bị quàng thêm trách nhiệm thu tiền bảo hiểm y tế.",
#  'Võ Nhật Vinh',
#  'Quyết định về nước của một du học sinh thường bị lãng mạn hóa, coi như sự hy sinh cơ hội, để trở về đóng góp cho quê hương.',
#  'Bùi Minh Đức',
#  "Chó dữ vẫn thường xuyên cắn người, cả khi chủ chó vừa dứt lời 'nó không làm gì đâu'.",
#  'Tô Thức',
#  "Miền Tây đang nỗ lực thoát khỏi 'ba vòng xoáy đi xuống' để níu giữ người dân ở lại trên mảnh đất này.",
#  'Trần Hữu Hiệp',
#  'Mức đấu giá khởi điểm 20 triệu đồng áp với các tỉnh thành là quá cao, khó thu hút đông người tham gia.',
#  'Lê Trần Quỳnh',
#  'Các loài cây như: trứng cá, hoa sữa, đa, si... không thích hợp trồng ven đường phố.',
#  'Trình Phương Quân',
#  'Người lao động khu vực tư nhân được tăng lương hàng năm, công viên chức chưa được tăng lương lần nào trong bốn năm.',
#  'Nguyễn Quốc Định',
#  'Thu phí đậu ôtô qua thẻ ETC là một giải pháp đáng cân nhắc.',
#  'Vũ Ngọc Bảo',
#  'Các khó khăn mà ngành y đang gặp phải không phải do lỗi của BHYT, mà vì chúng ta còn nghèo.',
#  'Quan Thế Dân',
#  'Tác nhân mới nhất gây ô nhiễm thị giác tại trung tâm các đô thị lớn ở Việt Nam hiện nay là graffiti (vẽ tranh đường phố).',
#  'Mark A. Ashwill',
#  'Câu chuyện\xa0của Rishi Sunak làm tôi liên tưởng đến viễn cảnh người Việt cũng được thăng tiến tương tự.',
#  'Nguyễn Văn Tuấn',
#  'Trong bối cảnh càng chống càng ngập, kinh nghiệm sống chung với con nước là điều cần tính đến.',
#  'Trần Hữu Hiệp',
#  'Tôi từng lặng đi trước những giọt nước mắt của người cha bất hạnh vào một buổi sáng lạnh tái tê trong khuôn viên tòa án.',
#  'Đặng Huyền',
#  "'Người mua trái phiếu liên quan đến tập đoàn Vạn Thịnh Phát có được trả tiền không?'",
#  'Hồ Quốc Tuấn',
#  "Chủ cửa hàng xăng dầu ở miền Tây than vãn với tôi khi buộc phải đóng cửa: ‘Gồng hết nổi rồi anh ơi. Bán nhiều, lỗ nhiều'...",
#  'Trần Hữu Hiệp',
#  'Bắt học sinh đi học sớm không thể là một giải pháp chính sách\xa0lâu dài và hiệu quả.',
#  'Nguyễn Kiều Hưng',
#  'Việt Nam có điều kiện thuận lợi để phát triển ngành nuôi trồng thủy sản biển và không nên để phí cơ hội này.',
#  'Josh Goldman',
#  'Sẽ là điều đáng tiếc cho thị trường và tổn thất cho nhà đầu tư nếu tìm cách bán lại mọi trái phiếu bằng mọi giá.',
#  'Nguyễn Quang Thuân']

# %%
#get_text() sẽ lấy tất cả các "text" đang hiển thị trong trang web
from pprint import pprint
full_text_by_get_text = bs.get_text()
pprint(full_text_by_get_text)
# Out:
# ('\n'
#  '\n'
#  '\n'
#  'Góc nhìn - Chia sẻ quan điểm, ý kiến, kinh nghiệm - VnExpress \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '  \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  ' \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Thứ ba, 8/11/2022\n'
#  '\n'
#  '\n'
#  'Mới nhất\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Tin theo khu vực\n'
#  '\n'
#  '\n'
#  'Hà Nội\n'
#  'TP Hồ Chí Minh\n'
#  '\n'
#  '\n'
#  'International\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Mới nhất\n'
#  '\n'
#  '\n'
#  'Thời sự \n'
#  '\n'
#  '\n'
#  '\n'
#  'Góc nhìn \n'
#  '\n'
#  '\n'
#  '\n'
#  'Thế giới \n'
#  '\n'
#  '\n'
#  '\n'
#  'Video \n'
#  '\n'
#  '\n'
#  '\n'
#  'Podcasts \n'
#  '\n'
#  '\n'
#  '\n'
#  'Kinh doanh \n'
#  '\n'
#  '\n'
#  '\n'
#  'Khoa học \n'
#  '\n'
#  '\n'
#  '\n'
#  'Giải trí \n'
#  '\n'
#  '\n'
#  '\n'
#  'Thể thao \n'
#  '\n'
#  '\n'
#  '\n'
#  'Pháp luật \n'
#  '\n'
#  '\n'
#  '\n'
#  'Giáo dục \n'
#  '\n'
#  '\n'
#  '\n'
#  'Sức khỏe \n'
#  '\n'
#  '\n'
#  '\n'
#  'Đời sống \n'
#  '\n'
#  '\n'
#  '\n'
#  'Du lịch \n'
#  '\n'
#  '\n'
#  '\n'
#  'Số hóa \n'
#  '\n'
#  '\n'
#  '\n'
#  'Xe \n'
#  '\n'
#  '\n'
#  '\n'
#  'Ý kiến \n'
#  '\n'
#  '\n'
#  '\n'
#  'Tâm sự \n'
#  '\n'
#  '\n'
#  '\n'
#  'Hài \n'
#  '\n'
#  'Tất cả \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Góc nhìn\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Tác giả\n'
#  '\n'
#  '\n'
#  'Lê Huy Khoa\n'
#  '\n'
#  '\n'
#  'Nguyễn Kiều Hưng\n'
#  '\n'
#  '\n'
#  'Lưu Đình Long\n'
#  '\n'
#  '\n'
#  'Nguyễn Văn Tuấn\n'
#  '\n'
#  '\n'
#  'Nguyễn Khắc Giang\n'
#  '\n'
#  '\n'
#  'Bạch Ngọc Chiến\n'
#  '\n'
#  '\n'
#  'Nguyễn Quang Thuân\n'
#  '\n'
#  '\n'
#  'Josh Goldman\n'
#  '\n'
#  '\n'
#  'Đặng Hùng Võ\n'
#  '\n'
#  '\n'
#  'Đặng Huyền\n'
#  '\n'
#  '\n'
#  'Xem thêm »\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Quá tải nhi khoa\n'
#  '\n'
#  '\n'
#  'Nhiều phụ huynh nôn nóng muốn trẻ khỏi bệnh ngay, nên đã cho con dùng kháng '
#  'sinh, kháng viêm khi chưa cần thiết.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Quan Thế Dân\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  "Giáo viên đi 'đòi nợ'\n"
#  '\n'
#  '\n'
#  "Giáo viên vô tình trở thành lực lượng 'đòi nợ' khi bị quàng thêm trách nhiệm "
#  'thu tiền bảo hiểm y tế.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Võ Nhật Vinh\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Du học sinh về nước\n'
#  '\n'
#  '\n'
#  'Quyết định về nước của một du học sinh thường bị lãng mạn hóa, coi như sự hy '
#  'sinh cơ hội, để trở về đóng góp cho quê hương.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Bùi Minh Đức\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Thú cưng dữ dằn\n'
#  '\n'
#  '\n'
#  "Chó dữ vẫn thường xuyên cắn người, cả khi chủ chó vừa dứt lời 'nó không làm "
#  "gì đâu'.\t\n"
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Tô Thức\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Miền Tây muốn thoát nghèo\n'
#  '\n'
#  '\n'
#  "Miền Tây đang nỗ lực thoát khỏi 'ba vòng xoáy đi xuống' để níu giữ người dân "
#  'ở lại trên mảnh đất này.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Trần Hữu Hiệp\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  "Xe sang biển số 'độc'\n"
#  '\n'
#  '\n'
#  'Mức đấu giá khởi điểm 20 triệu đồng áp với các tỉnh thành là quá cao, khó '
#  'thu hút đông người tham gia.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Lê Trần Quỳnh\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Chạy trốn mùi hoa sữa\n'
#  '\n'
#  '\n'
#  'Các loài cây như: trứng cá, hoa sữa, đa, si... không thích hợp trồng ven '
#  'đường phố.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Trình Phương Quân\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Vì sao nên sớm tăng lương?\n'
#  '\n'
#  '\n'
#  'Người lao động khu vực tư nhân được tăng lương hàng năm, công viên chức chưa '
#  'được tăng lương lần nào trong bốn năm.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Nguyễn Quốc Định\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Ám ảnh chỗ đậu xe\n'
#  '\n'
#  '\n'
#  'Thu phí đậu ôtô qua thẻ ETC là một giải pháp đáng cân nhắc.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Vũ Ngọc Bảo\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Ấm ức vì nghèo\n'
#  '\n'
#  '\n'
#  'Các khó khăn mà ngành y đang gặp phải không phải do lỗi của BHYT, mà vì '
#  'chúng ta còn nghèo.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Quan Thế Dân\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Bôi bẩn thành phố\n'
#  '\n'
#  '\n'
#  'Tác nhân mới nhất gây ô nhiễm thị giác tại trung tâm các đô thị lớn ở Việt '
#  'Nam hiện nay là graffiti (vẽ tranh đường phố).\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Mark A. Ashwill\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Chuyện của Thủ tướng Anh\n'
#  '\n'
#  '\n'
#  'Câu chuyện\xa0của Rishi Sunak làm tôi liên tưởng đến viễn cảnh người Việt '
#  'cũng được thăng tiến tương tự.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Nguyễn Văn Tuấn\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Tiền đổ xuống, nước dâng lên\n'
#  '\n'
#  '\n'
#  'Trong bối cảnh càng chống càng ngập, kinh nghiệm sống chung với con nước là '
#  'điều cần tính đến.\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Trần Hữu Hiệp\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Chủ đề\n'
#  '\n'
#  'Chính trị & chính sách\n'
#  'Y tế & sức khỏe\n'
#  'Kinh doanh & quản trị\n'
#  'Giáo dục & tri thức\n'
#  'Môi trường\n'
#  'Văn hóa & lối sống\n'
#  'Covid-19\n'
#  '\n'
#  '\n'
#  '\n'
#  'Đọc nhiều\n'
#  '\n'
#  '\n'
#  'Giúp việc cho con\n'
#  '\n'
#  'Tôi từng lặng đi trước những giọt nước mắt của người cha bất hạnh vào một '
#  'buổi sáng lạnh tái tê trong khuôn viên tòa án.\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Đặng Huyền\n'
#  '\n'
#  '\n'
#  '\n'
#  'Ai trả tiền trái phiếu?\n'
#  '\n'
#  "'Người mua trái phiếu liên quan đến tập đoàn Vạn Thịnh Phát có được trả tiền "
#  "không?'\n"
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Hồ Quốc Tuấn\n'
#  '\n'
#  '\n'
#  '\n'
#  'Nghịch lý bán xăng\n'
#  '\n'
#  'Chủ cửa hàng xăng dầu ở miền Tây than vãn với tôi khi buộc phải đóng cửa: '
#  "‘Gồng hết nổi rồi anh ơi. Bán nhiều, lỗ nhiều'...\n"
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Trần Hữu Hiệp\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Bình luận nhiều\n'
#  '\n'
#  '\n'
#  'Bắt trẻ đi học sớm\n'
#  'Bắt học sinh đi học sớm không thể là một giải pháp chính sách\xa0lâu dài và '
#  'hiệu quả.\xa0\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Nguyễn Kiều Hưng\n'
#  '\n'
#  '\n'
#  '\n'
#  'Tăng trưởng thông minh\n'
#  'Việt Nam có điều kiện thuận lợi để phát triển ngành nuôi trồng thủy sản biển '
#  'và không nên để phí cơ hội này.\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Josh Goldman\n'
#  '\n'
#  '\n'
#  '\n'
#  'Thu nợ trái phiếu\n'
#  'Sẽ là điều đáng tiếc cho thị trường và tổn thất cho nhà đầu tư nếu tìm cách '
#  'bán lại mọi trái phiếu bằng mọi giá.\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Nguyễn Quang Thuân\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Xem thêm\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  ' \n'
#  '\n'
#  ' \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n')
